# %% [markdown]
# ***[source](https://www.geeksforgeeks.org/python-pandas-dataframe/)***
# <br />
# ![What is Coloumn, Row and Frame](https://media.geeksforgeeks.org/wp-content/uploads/finallpandas.png "data")

# %%
# %pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 KB 4.9 MB/s eta 0:00:005.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/m.moosavi/.cache/pypoetry/virtualenvs/geeksdatascience-SuOnHxfp-py3.8/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install requests
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/home/m.moosavi/.cache/pypoetry/virtualenvs/geeksdatascience-SuOnHxfp-py3.8/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests

# %%
def _get_csv(source):
    return requests.get(source)

# %% [markdown]
# ## Show List

# %%
lst = ['Geeks', 'For', 'Geeks', 'is', 
            'portal', 'for', 'Geeks']

# %%
df = pd.DataFrame(lst)

# %%
df
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %% [markdown]
# ## Column Selection

# %%
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)

# %%
df[['Name', 'Qualification']]
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %% [markdown]
# ## Row Selection

# %%
data_college = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", index_col="College")

# %%
data_college
# Out:
#                             Name            Team  Number Position   Age  \
# College
# Texas              Avery Bradley  Boston Celtics     0.0       PG  25.0
# Marquette            Jae Crowder  Boston Celtics    99.0       SF  25.0
# Boston University   John Holland  Boston Celtics    30.0       SG  27.0
# Georgia State        R.J. Hunter  Boston Celtics    28.0       SG  22.0
# NaN                Jonas Jerebko  Boston Celtics     8.0       PF  29.0
# ...                          ...             ...     ...      ...   ...
# Butler              Shelvin Mack       Utah Jazz     8.0       PG  26.0
# NaN                    Raul Neto       Utah Jazz    25.0       PG  24.0
# NaN                 Tibor Pleiss       Utah Jazz    21.0        C  26.0
# Kansas               Jeff Withey       Utah Jazz    24.0        C  26.0
# NaN                          NaN             NaN     NaN      NaN   NaN
#
#                   Height  Weight     Salary
# College
# ...

# %%
data_college.loc["Texas"]
# Out:
#                       Name                   Team  Number Position   Age  \
# College
# Texas        Avery Bradley         Boston Celtics     0.0       PG  25.0
# Texas          Cory Joseph        Toronto Raptors     6.0       PG  24.0
# Texas          P.J. Tucker           Phoenix Suns    17.0       SF  31.0
# Texas     Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0
# Texas         Myles Turner         Indiana Pacers    33.0       PF  20.0
# Texas      Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0
# Texas    LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0
# Texas        D.J. Augustin         Denver Nuggets    12.0       PG  28.0
# Texas         Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0
#
#         Height  Weight      Salary
# College
# Texas      6-2   180.0   7730337.0
# Texas      6-3   190.0   7000000.0
# Texas      6-6   245.0   5500000.0
# Texas      6-9   238.0  14260870.0
# Texas     6-11   243.0   2357760.0
# ...

# %%
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv", index_col="Name")
print(data.loc["Avery Bradley"],'\n***\n', data.loc["R.J. Hunter"])
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
# ***
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %% [markdown]
# ## Subset Selection
# **Indexing** in pandas means simply selecting particular rows and columns of data from a DataFrame. Indexing could mean selecting all the rows and some of the columns, some of the rows and all of the columns, or some of each of the rows and columns. Indexing can also be known as ***Subset Selection***.

# %%
data.isnulll()
# Out:
#                 Team  Number  Position    Age  Height  Weight  College  Salary
# Name
# Avery Bradley  False   False     False  False   False   False    False   False
# Jae Crowder    False   False     False  False   False   False    False   False
# John Holland   False   False     False  False   False   False    False    True
# R.J. Hunter    False   False     False  False   False   False    False   False
# Jonas Jerebko  False   False     False  False   False   False     True   False
# ...              ...     ...       ...    ...     ...     ...      ...     ...
# Shelvin Mack   False   False     False  False   False   False    False   False
# Raul Neto      False   False     False  False   False   False     True   False
# Tibor Pleiss   False   False     False  False   False   False     True   False
# Jeff Withey    False   False     False  False   False   False    False   False
# NaN             True    True      True   True    True    True     True    True
#
# ...

# %%
data.fillna("Hi")
# Out:
#                          Team Number Position   Age Height Weight  \
# Name
# Avery Bradley  Boston Celtics    0.0       PG  25.0    6-2  180.0
# Jae Crowder    Boston Celtics   99.0       SF  25.0    6-6  235.0
# John Holland   Boston Celtics   30.0       SG  27.0    6-5  205.0
# R.J. Hunter    Boston Celtics   28.0       SG  22.0    6-5  185.0
# Jonas Jerebko  Boston Celtics    8.0       PF  29.0   6-10  231.0
# ...                       ...    ...      ...   ...    ...    ...
# Shelvin Mack        Utah Jazz    8.0       PG  26.0    6-3  203.0
# Raul Neto           Utah Jazz   25.0       PG  24.0    6-1  179.0
# Tibor Pleiss        Utah Jazz   21.0        C  26.0    7-3  256.0
# Jeff Withey         Utah Jazz   24.0        C  26.0    7-0  231.0
# NaN                        Hi     Hi       Hi    Hi     Hi     Hi
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.iterrows()[0]
#
# TypeError: 'generator' object is not subscriptable
